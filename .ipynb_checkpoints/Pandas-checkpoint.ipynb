# %%
import pandas as pd 

data = {
    "Name": ["Ali", "Sara", "Ahmad", "Ali", None],
    "Marks": [54,45,35,345,None],
    "City": ["Lahore", "Karachi", "Islamabad", None,"Karachi"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks       City
# 0    Ali   54.0     Lahore
# 1   Sara   45.0    Karachi
# 2  Ahmad   35.0  Islamabad
# 3    Ali  345.0       None
# 4   None    NaN    Karachi
