# %%
import pandas as pd 

data = {
    "Name": ["Ali", "Sara", "Ahmad", "Ali", None],
    "Marks": [54,45,35,55,None],
    "City": ["Lahore", "Karachi", "Islamabad", None,"Karachi"]
}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       1 import pandas as pd
#       3 data = {
#       4     "Name": ["Ali", "Sara", "Ahmad", "Ali", None],
#       5     "Marks": [54,45,35,None],
#       6     "City": ["Lahore", "Karachi", "Islamabad", None,"Karachi"]
#       7 }
# ----> 8 df = pd.DataFrame(data)
#       9 print(df)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...
