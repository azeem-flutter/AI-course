# %%
10 
9
# Out:
# 9

# %%
a= 3
print(a)
# Out:
# 3

# %% [raw]
# print(2**2)

# %% [markdown]
# INPUTValues

# %%
print(input("Enter your name"))input always return string
# Out:
# Enter your name Azeem

# %% [markdown]
# Type Casting (Type change krna )

# %%
num = int(input("Enter number"))
print(num)
# Out:
# Enter number 2
# 2

# %%
num1 = int(input("Enter number1:"))
num2 = int(input("Enter number2:"))
print(num1 + num2)
# Out:
# Enter number1: 2
# Enter number2: 2
# 4

# %% [markdown]
# Comments (comment code explain krne k liye hothe hai )

# %%
# numbers 
a =5

# %% [markdown]
# MulitiComments

# %%
"""its a multiline
comments for
reading codes """
# Out:
# 'its a multiline\ncomments for\nreading codes '

# %% [markdown]
# String Operations

# %% [markdown]
# String Concatenation

# %%
first = "Azeem"
last = "jamil"
# string is immutable you can not modify it using index
last.replace('a','z')
print(last)
print(first + " "+ last)
# Out:
# jamil
# Azeem jamil

# %% [markdown]
# String Repetition

# %%
print("Azeem"*3)
# Out:
# AzeemAzeemAzeem

# %% [markdown]
# Indexing

# %%
word = "Python"
print(word[3])
print(word[-1])
print(word[-2])
# Out:
# h
# n
# o

# %% [markdown]
# Slicing (Part access krna)

# %%
word = "Artificial Intelligence"
print(word[0:13])
# Out:
# Artificial In

# %% [markdown]
# Length of String

# %%
word = "Azeem"
print(len(word))
# Out:
# 5

# %% [markdown]
# String Methods

# %%
# Strip (Spaces Remove)
text = "   AI   "
print(text.strip())
# Strip (Spaces Remove)
text = "Hello AI"
print(text.replace("AI", "World"))
# Replace
text = "Hello AI"
print(text.replace("AI", "World"))
# Split
text = "AI is powerful"
a = text.split()
b = a[0]
print(b)
print(text.split())
# Find
text = "Artificial Intelligence"
print(text.find("Intelligence"))
# Out:
# AI
# Hello World
# Hello World
# AI
# ['AI', 'is', 'powerful']
# 11

# %% [markdown]
# String Formating

# %%
name = "Azeem"
age = 30
# this is the old method 
print("My name is ", name, "my age is", age)
# this is the Professional Method 
print(f"My name is {name} and I am {age} years old ")
# Out:
# My name is  Azeem my age is 30
# My name is Azeem and I am 30 years old

# %% [markdown]
# Checking In String

# %%
text = "AI engineer"
print("AI" in text)
# Out:
# True

# %% [markdown]
# Escape Characters

# %%
print("Hello\nWorld")
print("Hello\tWorld")
print("Hello\"World")
print("HelloWorld")
# Out:
# Hello
# World
# Hello	World
# Hello"World
# HelloWorld

# %% [markdown]
# List

# %% [markdown]
# List ik order collection hothi hai jis mei muliple values store ho skthi hai
# List Features
#
# ✔ Ordered
# ✔ Changeable (mutable)
# ✔ Duplicate allowed
# ✔ Different data types allowed

# %% [markdown]
# 1) Acessing element (indexing)

# %%
list = [1,2,3,4,"Ali"]

print(list[1])
print(list[-1])
# Out:
# 2
# Ali

# %% [raw]
# 2) Slicing

# %%
list = [1,12,123,22,34,5, "Ali"]
print(list[0:2])
print(list[0:-1])
# Out:
# [1, 12]
# [1, 12, 123, 22, 34, 5]

# %% [markdown]
# 3) Modify List

# %%
list =[1,2,3,5,6,6]
list[0]=0
print(list)
# Out:
# [0, 2, 3, 5, 6, 6]

# %% [markdown]
# List Methods "

# %% [markdown]
# list =[1,1,2,45,5,66,7]
# # Append() Method Add values in the end of the list
# list.append(4)
# print(list)
#
# #insert() Add values in specific position
# list.insert(1,50)
# print(list)
# #remove() use to delete value
# list.remove(50)
# print(list)
# #pop() delete values by passing index(not values like in remove method)
# list.pop(0)
# print(list)
# #len() method is used to check length of the list
# print(len(list))
# #sort() method is used to sort element
# #sort() mehtod is not supported between instances of 'str' and 'int'
# list.sort()
# print(list)

# %% [markdown]
# Set
# set unordered collection hotha hai
# dupicate values allow nai hothi

# %%
numbers= {1,2,3,4,5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 🔹 Important Points
#
# ✔ Unordered (index nahi hota)
# ✔ Unique elements only
# ✔ Mutable
# ✔ Curly braces { } use hoti hain

# %% [markdown]
# add() Method

# %%
numbers= {1,2,3,4}
numbers.add(5)
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 2) remove() elment remove krtha hai  agr value na ho tu error detha hai

# %%
numbers.remove(4)
print(numbers)
# Out:
# {1}

# %% [markdown]
# 3) discard() remove krtha hai without any error

# %%
n ={1,2,3,4,5}
n.discard(3)
print(n)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# 4) pop() random element remove krtha hai

# %%
num = {1,2,3,4,5}
num.pop()
print(num)
# Out:
# {2, 3, 4, 5}

# %% [markdown]
# 5) clear() sab remove krtha hai

# %%
num.clear()
print(num)
# Out:
# set()

# %%
#Set Operations (Math jaisi)
#Union (Combine)
A = {1,2,3}
B = {3,4,5}

print(A.union(B))
{1, 2, 3, 4, 5}
#Intersection (Common elements)
print(A.intersection(B))
{3}
#Difference
print(A.difference(B))
{1, 2}
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2}

# %% [markdown]
# Tuple
# tuple bi list jaisa hotha hai lakin is ko change nai kr sktha
# Tuple Features
#
# ✔ Ordered
# ✔ Immutable (change nahi ho sakta)
# ✔ Duplicate allowed
# ✔ Faster than list

# %%
# Access Element
point= (1,2)
print(point[0]) # return 0 index value 
# tuple modify nai hotha 
#point[0]=50 # its give error because tuple do not modify

#Single element tuple
t=(5)
print(t)
#Tuple packing and unpacking
data = (1,2,3)
a,b,c = data
print(a,b,c)
# Out:
# 1
# 5
# 1 2 3

# %%
# ===================== TUPLE METHODS =====================

# In Python, tuple has only 2 built-in methods:
# 1) count()  → Returns the number of times a specified value appears.
# 2) index()  → Returns the index of the first occurrence of a specified value.

# ===================== IMPORTANT NOTE =====================

# Tuple is IMMUTABLE.
# That means:
# ✔ Values can be accessed
# ✘ Insert, append, remove, or modify operations are NOT allowed.

# ===================== ALLOWED OPERATIONS =====================

# 1) Indexing        → Access element using position number.
# 2) Slicing         → Access a range of elements.
# 3) len()           → Returns total number of elements.
# 4) Membership test → Using 'in' to check if value exists.
# 5) Iteration       → Using loop to traverse elements.

# ===================== EXAMPLE =====================

t = (5, 10, 15, 20, 5)

print(t.count(5))     # count()
print(t.index(10))    # index()
print(len(t))         # length
print(15 in t)        # membership
print(t[1:4])         # slicing
print(t[2])           # indexing

for x in t:           # iteration
    print(x)
# Out:
# 2
# 1
# 5
# True
# (10, 15, 20)
# 15
# 5
# 10
# 15
# 20
# 5

# %%
# ===================== DICTIONARY (dict) =====================

# Dictionary is a built-in data structure used to store data in key-value pairs.
# It is mutable (values can be changed).
# Keys must be unique and immutable (string, number, tuple).
# Values can be of any data type.

# Example:
student = {
    "name": "Ali",
    "age": 21,
    "course": "CS",
    "marks": [80, 85, 90]
}

# ===================== IMPORTANT POINTS =====================

# ✔ Key-value based structure
# ✔ Mutable (can add, update, remove)
# ✔ Keys are unique
# ✔ Ordered (Python 3.7+)

# ===================== DICTIONARY METHODS =====================

# 1) keys()    → Returns all keys
# 2) values()  → Returns all values
# 3) items()   → Returns key-value pairs
# 4) get()     → Returns value of a key safely
# 5) update()  → Updates dictionary
# 6) pop()     → Removes specific key
# 7) clear()   → Removes all elements

# ===================== OPERATIONS EXAMPLE =====================

print(student.keys())        # keys()
print(student.values())      # values()
print(student.items())       # items()
print(student.get("name"))   # get()
student.update({"age": 22})  # update()
student.pop("course")        # pop()
print(student)
student.clear()              # clear()
print(student)
# Out:
# dict_keys(['name', 'age', 'course', 'marks'])
# dict_values(['Ali', 21, 'CS', [80, 85, 90]])
# dict_items([('name', 'Ali'), ('age', 21), ('course', 'CS'), ('marks', [80, 85, 90])])
# Ali
# {'name': 'Ali', 'age': 22, 'marks': [80, 85, 90]}
# {}

# %%
student = {
    "name":["Ali","Ammara","Amna","Abdulrehman"],
    "marks":[56,95,95,90]
}
for value in student.values():
    print(value)
# Out:
# ['Ali', 'Ammara', 'Amna', 'Abdulrehman']
# [56, 95, 95, 90]
